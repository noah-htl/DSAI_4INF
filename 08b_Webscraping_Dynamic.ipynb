# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.youtube.com/@TomScottGo/videos"
request = requests.get(url)
request
# Out:
# <Response [200]>

# %%
html = BeautifulSoup(request.content, "html.parser")

# %%
html.find_all("a", {"id":"video-title-link"})
# Out:
# []

# %%
"years" in request.text
# Out:
# True

# %%
"ten years" in request.text
# Out:
# True

# %%
index = request.text.index("ten years")
request.text[index-100:index+100]
# Out:
# '6rs=AOn4CLBero7KiugLSbH0DyzcyROzaQ0kNw","width":336,"height":188}]},"title":{"runs":[{"text":"After ten years, it\'s time to stop weekly videos."}],"accessibility":{"accessibilityData":{"label":"After '

# %%
index = request.text.index("ten years", index+1)
request.text[index-100:index+100]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 index = request.text.index("ten years", index+1)
#       2 request.text[index-100:index+100]
#
# ValueError: substring not found
