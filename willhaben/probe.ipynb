# %%
import scraping
import sklearn as sk
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split

# %%
#data = scraping.scrape(301,500)
#data.dropna()
#data.to_csv("./data.csv", mode='a', header=False)

# %%
data = pd.read_csv("./data.csv")

# %%
data[data.price == data.price.max()]
# Out:
#       Unnamed: 0     price         teaser     plz bundesland  \
# 9306  1991753679  119900.0  Andere Marken  1030.0       Wien
#
#                                     description
# 9306  Patek Philippe 5726/1A-14 Annual Calendar

# %%
df_binary = data[['plz', 'price']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['plz', 'price']
#display the first 5 rows
df_binary.head()
# Out:
#       plz   price
# 0  1230.0    70.0
# 1  1220.0    80.0
# 2  1180.0  1900.0
# 3  1220.0    25.0
# 4  9020.0    50.0

# %%
sns.lmplot(x ="plz", y ="price", data = df_binary, order = 2, ci = None)
plt.show()
