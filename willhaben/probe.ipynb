# %%
import scraping

# %%
data = scraping.scrape(1,20)
# Out:
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'
# error invalid literal for int() with base 10: '110 00'

# %%
data.dropna()
data.to_csv("./data.csv")

# %%
data[data.price == data.price.max()]
# Out:
#               price teaser     plz        bundesland  \
# 1741324292  89000.0  Rolex  2500.0  Niederösterreich
#
#                                                   description
# 1741324292  Rolex GMT Master II Ref.116748SARU + Ankauf, V...
