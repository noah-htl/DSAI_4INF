# %%
import scraping

# %%
data = scraping.scrape(301,500)
# Out:
# error invalid literal for int() with base 10: '6515HP'
# error invalid literal for int() with base 10: 'H-2500'
# error invalid literal for int() with base 10: 'H-2500'
# error invalid literal for int() with base 10: '925 07'
# error invalid literal for int() with base 10: 'Freilassing'

# %%
data.dropna()
data.to_csv("./data.csv", mode='a', header=False)

# %%
data[data.price == data.price.max()]
# Out:
#               price         teaser      plz            bundesland  \
# 843146804  115990.0  Andere Marken  74321.0  Bietigheim-Bissingen
#
#                                   description
# 843146804  Patek Philippe Cubitus 7128/1G-001
